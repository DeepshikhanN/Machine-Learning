# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import scipy.stats as stats

# %%
import seaborn as sns

# %%
import copy
import statsmodels.api as sm
from sklearn.preprocessing import LabelEncoder
# %matplotlib inline

# %%
sns.set()#seting the default seaborn style for our plots

# %%
df=pd.read_csv('https://raw.githubusercontent.com/Premalatha-success/Statistics/main/insurance%20(2).csv')

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
sns.relplot(x='age',y='bmi',hue='children',data=df)

# %%
sns.catplot(x='age',y='children',jitter=True,data=df)

# %%
df.sample()
# Out:
#       age   sex    bmi  children smoker     region    charges
# 1327   51  male  30.03         1     no  southeast  9377.9047

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.sort_values('age')
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1248   18  female  39.820         0     no  southeast   1633.96180
# 482    18  female  31.350         0     no  southeast   1622.18850
# 492    18  female  25.080         0     no  northeast   2196.47320
# 525    18  female  33.880         0     no  southeast  11482.63485
# 529    18    male  25.460         0     no  northeast   1708.00140
# ...   ...     ...     ...       ...    ...        ...          ...
# 398    64    male  25.600         2     no  southwest  14988.43200
# 335    64    male  34.500         0     no  southwest  13822.80300
# 378    64  female  30.115         3     no  northwest  16455.70785
# 1265   64    male  23.760         0    yes  southeast  26926.51440
# 635    64    male  38.190         0     no  northeast  14410.93210
#
# [1338 rows x 7 columns]

# %%
df.drop_duplicates()
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
df.max()
# Out:
# age                  64
# sex                male
# bmi               53.13
# children              5
# smoker              yes
# region        southwest
# charges     63770.42801
# dtype: object

# %%
df.min()
# Out:
# age                18
# sex            female
# bmi             15.96
# children            0
# smoker             no
# region      northeast
# charges     1121.8739
# dtype: object

# %%
sns.set()

# %%
    plt.figure(figsize=(8,6))
    sns.scatterplot(df.age,df.charges,hue=df.smoker,palette=['blue','orange'],alpha=0.7)
    plt.show()
# Out:
# C:\Users\Shikha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#T-test to check the dependency of smoking on charges
Ho='Charges of smokers and non-smokers are same'#stating null hypothethis
Ha='Charges of smokers and non-smokers are not the same'#stating alternate hypothethis

x=np.array(df[df.smoker=='yes'].charges)#selectng charges corres to smokers as an array
y=np.array(df[df.smoker=='no'].charges)#selectng charges corres to non-smokers as an array
t,p_value=stats.ttest_ind(x,y,axis=0)#performing an Independent T-test
if p_value<0.05:#setting our significance level at 5%
    print(Ha)
else:
    print(Ho)
print(p_value)
# Out:
# Charges of smokers and non-smokers are not the same
# 8.271435842179102e-283

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
sns.pairplot(df)

# %%
sns.relplot(x='sex',y='bmi',data=df)

# %%
#plots to see the distribution of continous features individually
plt.figure(figsize=(20,15))
plt.subplot(1,3,1)
plt.hist(df.bmi,color='lightblue',edgecolor='black',alpha=0.7)
plt.xlabel('bmi')

plt.subplot(1,3,2)
plt.hist(df.age,color='lightblue',edgecolor='black',alpha=0.7)
plt.xlabel('age')

plt.subplot(1,3,3)
plt.hist(df.charges,color='lightblue',edgecolor='black',alpha=0.7)
plt.xlabel('charges')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Skewness=pd.DataFrame({'Skewness':[stats.skew(df.bmi),stats.skew(df.age),stats.skew(df.charges)]},
                      index=['bmi','age','charges'])#Measure the skewness of the required columns
Skewness
# Out:
#          Skewness
# bmi      0.283729
# age      0.055610
# charges  1.514180

# %%
plt.figure(figsize=(20,15))
plt.subplot(3,1,1)
sns.boxplot(x=df.bmi,color='lightblue')

plt.subplot(3,1,2)
sns.boxplot(x=df.age,color='lightblue')

plt.subplot(3,1,3)
sns.boxplot(x=df.charges,color='lightblue')

plt.show()

# %%
plt.figure(figsize=(20,15))

x=df.smoker.value_counts().index  #values for x axis
y=[df['smoker'].value_counts()[i] for i in x]# count of each class on y axis

plt.subplot(4,2,1)
plt.bar(x,y,align='center',color='lightblue',edgecolor='black',alpha=0.7)
plt.xlabel('Smoker?')
plt.ylabel('Count')
plt.title('Smoker Distribution')

x1=df.sex.value_counts().index # values for x axis
y1=[df['sex'].value_counts()[j] for j in x1]

plt.subplot(4,2,2)
plt.bar(x1,y1,align='center',color='lightblue',edgecolor='black',alpha=0.7)
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender Distribution')

x2=df.region.value_counts().index # values for x axis
y2=[df['region'].value_counts()[k] for k in x2]

plt.subplot(4,2,3)
plt.bar(x2,y2,align='center',color='lightblue',edgecolor='black',alpha=0.7)
plt.xlabel('Region')
plt.ylabel('Count')
plt.title('Regions Distribution')

x3=df.children.value_counts().index # values for x axis
y3=[df['children'].value_counts()[l] for l in x3]

plt.subplot(4,2,4)
plt.bar(x3,y3,align='center',color='lightblue',edgecolor='black',alpha=0.7)
plt.xlabel('No of Children')
plt.ylabel('Count')
plt.title('Children Distribution')

plt.show()

# %%
crosstab=pd.crosstab(df['sex'],df['smoker'])
crosstab
# Out:
# smoker   no  yes
# sex
# female  547  115
# male    517  159

# %%
#T-Test for checking if Gender has an effect on bmi
Ho='Gender has no effect on bmi'#stating null hypothethis
Ha='Gender has effect on bmi'#stating alternate hypothethis

x=np.array(df[df.sex=='male'].bmi)#selectng charges corres to smokers as an array
y=np.array(df[df.sex=='female'].bmi)#selectng charges corres to non-smokers as an array
t,p_value=stats.ttest_ind(x,y,axis=0)#performing an Independent T-test
if p_value<0.05:#setting our significance level at 5%
    print(f'{Ha} as the p_value({p_value.round()})<0.05')
else:
    print(f'{Ho} as the p_value({p_value.round(3)})>0.05')
print(p_value)
# Out:
# Gender has no effect on bmi as the p_value(0.09)>0.05
# 0.08997637178984932

# %%
#Chi square testing to check if smoking habits are different for different genders
Ho='Gender has no effect on smoking habits'
Ha='Gender has effect on smoking habits'
crosstab=pd.crosstab(df['sex'],df['smoker'])#Contingency table of sex and smoker attributes
chi,p_value,dof,expected=stats.chi2_contingency(crosstab)
if p_value<0.05:
    print(f'{Ha} as the p_value({p_value.round()})<0.05')
else:
    print(f'{Ho} as the p_value({p_value.round(3)})>0.05')
crosstab
# Out:
# Gender has effect on smoking habits as the p_value(0.0)<0.05
# smoker   no  yes
# sex
# female  547  115
# male    517  159

# %%
#Chi square testing to check if smoking habits are different for different genders
Ho='Region has no effect on smoking habits'
Ha='Region has effect on smoking habits'
crosstab=pd.crosstab(df['region'],df['smoker'])#Contingency table of sex and smoker attributes
chi,p_value,dof,expected=stats.chi2_contingency(crosstab)
if p_value<0.05:
    print(f'{Ha} as the p_value({p_value.round(3)})<0.05')
else:
    print(f'{Ho} as the p_value({p_value.round(3)})<0.05')
crosstab
# Out:
# Region has no effect on smoking habits as the p_value(0.062)<0.05
# smoker      no  yes
# region
# northeast  257   67
# northwest  267   58
# southeast  273   91
# southwest  267   58

# %%
#Chi square testing to check if bmi of males is different from that of females
Ho='bmi is not significantly different between males and females'
Ha='bmi is significantly different between males and females'
crosstab=pd.crosstab(df['bmi'],df['sex'])
chi,p_value,dof,expected=stats.chi2_contingency(crosstab)
if p_value<0.05:
    print(f'{Ha} as the p_value({p_value.round(3)})<0.05')
else:
    print(f'{Ho} as the p_value({p_value.round(3)})<0.05')
crosstab
# Out:
# bmi is not significantly different between males and females as the p_value(0.7)<0.05
# sex     female  male
# bmi
# 15.960       0     1
# 16.815       1     1
# 17.195       1     0
# 17.290       2     1
# 17.385       0     1
# ...        ...   ...
# 48.070       1     0
# 49.060       0     1
# 50.380       0     1
# 52.580       0     1
# 53.130       0     1
#
# [548 rows x 2 columns]

# %%
    plt.figure(figsize=(8,6))
    sns.scatterplot(df.sex,df.charges,palette=['blue','orange'],alpha=0.7)
    plt.show()
# Out:
# C:\Users\Shikha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#T-test to check whether Gender has effect on charges
Ho='Gender has effect on charges'
Ha='Gender has no effect on charges'
crosstab=pd.crosstab(df['charges'],df['sex'])
chi,p_value,dof,expected=stats.chi2_contingency(crosstab)
if p_value<0.05:
    print(f'{Ha} as the p_value({p_value.round(3)})<0.05')
else:
    print(f'{Ho} as the p_value({p_value.round(3)})<0.05')
crosstab
# Out:
# Gender has effect on charges as the p_value(0.479)<0.05
# sex          female  male
# charges
# 1121.87390        0     1
# 1131.50660        0     1
# 1135.94070        0     1
# 1136.39940        0     1
# 1137.01100        0     1
# ...             ...   ...
# 55135.40209       1     0
# 58571.07448       1     0
# 60021.39897       0     1
# 62592.87309       0     1
# 63770.42801       1     0
#
# [1337 rows x 2 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
df1=pd.DataFrame({'Area':2500,3000,3500,4000,4500},'Price')
df1
# Out:
#   File "C:\Users\Shikha\AppData\Local\Temp/ipykernel_8056/2404899636.py", line 1
#     df1=pd.DataFrame({'Area':2500,3000,3500,4000,4500},'Price')
#                                       ^
# SyntaxError: invalid syntax
